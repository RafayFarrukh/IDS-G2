# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
dataset = pd.read_csv("rafay.csv")

# %%
dataset.head()
# Out:
#                   Name  Gender HSSC-1 HSSC-2  CGPA FavoriteColor BirthMonth  \
# 0       Muhammad Usman    Male    440    369   2.8         Black      March
# 1          Taha Ishfaq    Male    415    408  2.73           Red      March
# 2      Muhammad Hamdan    Male    388    321  2.78         Black    October
# 3  Syeda Maham Gillani  Female    412    440  3.11          Blue   February
# 4           Umar Wasim    Male    364    469  2.42         black   October
#
#   Weight First Name Middle Name Last Name Unnamed: 11 Unnamed: 12
# 0     77   Muhammad       Usman       NaN         NaN         NaN
# 1     72       Taha      Ishfaq       NaN         NaN         NaN
# 2     53   Muhammad      Hamdan       NaN         NaN         NaN
# 3     63      Syeda       Maham   Gillani         NaN         NaN
# 4     80       Umar       Wasim       NaN         NaN         NaN

# %%
new_df = dataset[['Name']].copy()
print(new_df)
# Out:
#                     Name
# 0         Muhammad Usman
# 1            Taha Ishfaq
# 2        Muhammad Hamdan
# 3    Syeda Maham Gillani
# 4             Umar Wasim
# ..                   ...
# 129     M Abubakar Malik
# 130         Muhammad Ali
# 131         shafaqat ali
# 132          Ammar Asif
# 133      Muhammad Zubair
#
# [134 rows x 1 columns]

# %%
dataset[dataset['Name'].str.count('^[H].*')>0]
# Out:
#                     Name  Gender HSSC-1 HSSC-2  CGPA FavoriteColor  \
# 9           Hamza Naveed    Male    954    459   2.8          Blue
# 21           Habib Ullah    Male    399    434  3.35       Mustard
# 22          Hunain Javed    Male    362    413  2.94         Black
# 58  Hafiz Malahim Labib.    Male    390    430  3.24        Orange
# 60   HAMNA TARIQ SALEEMI  Female    400    418   2.8         Black
# 77                  Hina  Female    410    350   2.9          Blue
# 78      Hamza Javed Khan    Male    400    381  3.39          Blue
# 80        Husnain Ahmed     Male    335    427  2.41     Dark blue
# 93      Hamayoun Masroor    Male    900    856  3.16          Pink
# 98         Hussain afzal    Male    415    346  2.87          Blue
#
#     BirthMonth Weight First Name Middle Name Last Name Unnamed: 11 Unnamed: 12
# 9          May     58      Hamza      Naveed       NaN         NaN         NaN
# 21       April     60      Habib       Ullah       NaN         NaN         NaN
# 22  September      76     Hunain       Javed       NaN         NaN         NaN
# 58         May     54      Hafiz     Malahim    Labib.         NaN         NaN
# 60     October     62      HAMNA       TARIQ   SALEEMI         NaN         NaN
# 77      August     67       Hina         NaN       NaN         NaN         NaN
# 78    January      78      Hamza       Javed      Khan         NaN         NaN
# 80   September     72    Husnain       Ahmed       NaN         NaN         NaN
# 93  September      63   Hamayoun     Masroor       NaN         NaN         NaN
# 98       March     81    Hussain       afzal       NaN         NaN         NaN

# %%
new_df[dataset['Name'].str.count('^[H].*')>0]
# Out:
#                     Name
# 9           Hamza Naveed
# 21           Habib Ullah
# 22          Hunain Javed
# 58  Hafiz Malahim Labib.
# 60   HAMNA TARIQ SALEEMI
# 77                  Hina
# 78      Hamza Javed Khan
# 80        Husnain Ahmed
# 93      Hamayoun Masroor
# 98         Hussain afzal

# %%
name_df = dataset[['Name','Middle Name','Last Name']].copy()
print(name_df)
# Out:
#                     Name Middle Name Last Name
# 0         Muhammad Usman       Usman       NaN
# 1            Taha Ishfaq      Ishfaq       NaN
# 2        Muhammad Hamdan      Hamdan       NaN
# 3    Syeda Maham Gillani       Maham   Gillani
# 4             Umar Wasim       Wasim       NaN
# ..                   ...         ...       ...
# 129     M Abubakar Malik    Abubakar     Malik
# 130         Muhammad Ali         Ali       NaN
# 131         shafaqat ali         ali       NaN
# 132          Ammar Asif         Asif       NaN
# 133      Muhammad Zubair      Zubair       NaN
#
# [134 rows x 3 columns]

# %%
dataset[dataset['Last Name'].str.count('w*')>0]
# Out:
#                               Name  Gender   HSSC-1    HSSC-2   CGPA  \
# 3              Syeda Maham Gillani  Female      412       440   3.11
# 6            Shahzada Mujahid Raza    Male      814       466    3.2
# 14           Muhammad Subhan Khan     Male      412       419   3.53
# 17            SARMAD WAHEED AHMED     Male      436       427   3.47
# 20               M Hassaan Lateef     Male      389       450    2.8
# 23                Ahmed Amjad Dar     Male      439       432   2.71
# 26         Muhammad Ibrahim Khalil    Male      340       357   2.88
# 32             Muhammad saim jamil    Male      320       849   2.85
# 33               Ahmar Hafeez Khan    Male      437       397   2.81
# 39            Muhammad Umar Asghar    Male      357       333   2.23
# 42            MUHAMMAD HAIDER AWAN    Male      60%       425   2.56
# 45             M.Abdul Mateen Alam    Male      345       390   2.93
# 46           Muhammad Ammar Khalid    Male  368/510       440   2.97
# 48              Osama Nadeem Khan     Male      350       389    2.8
# 51           Muhammad Hashir Azeem    Male      377       428    2.4
# 54               Muhammad Aun Raza    Male      339       320   2.96
# 55          Syeda Noor Zehra Naqvi  Female      428       420   3.05
# 58            Hafiz Malahim Labib.    Male      390       430   3.24
# 60             HAMNA TARIQ SALEEMI  Female      400       418    2.8
# 63          Bashara Tehseen Liaqat  Female      368       396   2.16
# 64        Muhammad zafar ijaz khan    Male      421       430    2.7
# 65            Muhammad Hammad Ejaz    Male      401       325    2.8
# 68             MUHAMMAD SAIF ULLAH    Male      293       799   3.11
# 69       Syed Muhammad Hamza Imran    Male      378       390   2.78
# 70               Muhammad Al Fahad    Male      412       346   2.35
# 72      Syed Ali Raza Shah Bukhari    Male      293       817  2.84.
# 76                 Abdul Hadi Khan    Male      315       368   3.23
# 78                Hamza Javed Khan    Male      400       381   3.39
# 83   Syed Muhammad Ali Abbas Naqvi    Male      380       341   2.65
# 96         Salman Wasi Ahmad Khan     Male      390       352   2.11
# 97           GHULAM MUSTAFA SHIEKH    Male      385       328   2.81
# 100        Muhammad Azeem Shoukat     Male      372       279   2.42
# 104          Muhammad Nouman Tahir    Male      412       442      3
# 106         Muhammad Huzaifa Jawad    Male      407       825    2.7
# 108                NOOR TARIQ RANA  Female      863       490   3.16
# 109        Muhammad Asadullah Rind    Male      374       404   2.69
# 110           Muhammad Talha Saeed    Male      382  768/1100   2.54
# 116           Muhammad Bilal Aslam    Male      421       400    2.6
# 117                 Syed Ali Mehdi    Male      384       829   2.57
# 118               Aftab Ahmad Khan    Male      494       422   2.27
# 122                 Syed Zain Raza    Male      394       436    2.8
# 123         Mutyyab Ul Hassan Khan    Male      383       441   2.58
# 124          Muhammad Umair Tariq     Male      402       407   3.45
# 129               M Abubakar Malik    Male      410       349   2.94
#
#     FavoriteColor BirthMonth Weight First Name Middle Name Last Name  \
# 3            Blue   February     63      Syeda       Maham   Gillani
# 6          Orange     August     60   Shahzada     Mujahid      Raza
# 14         Yellow   January      90   Muhammad      Subhan      Khan
# 17          Green    January   49.5     SARMAD      WAHEED     AHMED
# 20          Black  February      82          M     Hassaan    Lateef
# 23          Black       July     67      Ahmed       Amjad       Dar
# 26          Blue   November      60   Muhammad     Ibrahim    Khalil
# 32           blue   december     65   Muhammad        saim     jamil
# 33         Yellow   February     77      Ahmar      Hafeez      Khan
# 39          Black    October     62   Muhammad        Umar    Asghar
# 42           Blue    October     60   MUHAMMAD      HAIDER      AWAN
# 45        Purple   September     64    M.Abdul      Mateen      Alam
# 46          BLACK     August     72   Muhammad       Ammar    Khalid
# 48      Dark blue   February     53      Osama      Nadeem      Khan
# 51           Blue      March     53   Muhammad      Hashir     Azeem
# 54          Black    October     60   Muhammad         Aun      Raza
# 55         Yellow    October     67      Syeda        Noor     Zehra
# 58         Orange        May     54      Hafiz     Malahim    Labib.
# 60          Black    October     62      HAMNA       TARIQ   SALEEMI
# 63         Yellow   October      62    Bashara     Tehseen    Liaqat
# 64          Brown     August     64   Muhammad       zafar      ijaz
# 65    Light Green        May     52   Muhammad      Hammad      Ejaz
# 68         Black        June     66   MUHAMMAD        SAIF     ULLAH
# 69            Red   October      58       Syed    Muhammad     Hamza
# 70         Peach         May     54   Muhammad          Al     Fahad
# 72         Black     January     78       Syed         Ali      Raza
# 76          White       July     98      Abdul        Hadi      Khan
# 78           Blue   January      78      Hamza       Javed      Khan
# 83           Blue   Feburary     65       Syed    Muhammad       Ali
# 96           Blue     August     80     Salman        Wasi     Ahmad
# 97         Yellow   October      66     GHULAM     MUSTAFA    SHIEKH
# 100        Black   November      68   Muhammad       Azeem   Shoukat
# 104          Blue   February     59   Muhammad      Nouman     Tahir
# 106          Blue    October     60   Muhammad     Huzaifa     Jawad
# 108        Yellow    October     60       NOOR       TARIQ      RANA
# 109          Blue       July     60   Muhammad   Asadullah      Rind
# 110         Black      March     67   Muhammad       Talha     Saeed
# 116        Peach       March     74   Muhammad       Bilal     Aslam
# 117          Blue  December      68       Syed         Ali     Mehdi
# 118         Black   February     58      Aftab       Ahmad      Khan
# 122         Black   October      45       Syed        Zain      Raza
# 123         BLACK   October    80kg    Mutyyab          Ul    Hassan
# 124       Purple         May     65   Muhammad       Umair     Tariq
# 129          Blue   Feburary     65          M    Abubakar     Malik
#
#     Unnamed: 11 Unnamed: 12
# 3           NaN         NaN
# 6           NaN         NaN
# 14          NaN         NaN
# 17          NaN         NaN
# 20          NaN         NaN
# 23          NaN         NaN
# 26          NaN         NaN
# 32          NaN         NaN
# 33          NaN         NaN
# 39          NaN         NaN
# 42          NaN         NaN
# 45          NaN         NaN
# 46          NaN         NaN
# 48          NaN         NaN
# 51          NaN         NaN
# 54          NaN         NaN
# 55        Naqvi         NaN
# 58          NaN         NaN
# 60          NaN         NaN
# 63          NaN         NaN
# 64         khan         NaN
# 65          NaN         NaN
# 68          NaN         NaN
# 69        Imran         NaN
# 70          NaN         NaN
# 72         Shah     Bukhari
# 76          NaN         NaN
# 78          NaN         NaN
# 83        Abbas       Naqvi
# 96         Khan         NaN
# 97          NaN         NaN
# 100         NaN         NaN
# 104         NaN         NaN
# 106         NaN         NaN
# 108         NaN         NaN
# 109         NaN         NaN
# 110         NaN         NaN
# 116         NaN         NaN
# 117         NaN         NaN
# 118         NaN         NaN
# 122         NaN         NaN
# 123        Khan         NaN
# 124         NaN         NaN
# 129         NaN         NaN

# %%
dataset['CGPA'] = dataset.CGPA

# %%
import random

# %%
#  Plot a pie chart to show the ratio of male and female students.
male = dataset['Gender'].str.startswith('M').sum()
female = dataset['Gender'].str.startswith('F').sum()
gender = ["Male", "Female"]
data = [male, female]
plt.pie(data, labels=gender, autopct='%1.1f%%')
plt.title("Ratio of Male and Female Students")
plt.show()

# %%
print(dataset.dtypes)
# Out:
# Name             object
# Gender           object
# HSSC-1           object
# HSSC-2           object
# CGPA             object
# FavoriteColor    object
# BirthMonth       object
# Weight           object
# First Name       object
# Middle Name      object
# Last Name        object
# Unnamed: 11      object
# Unnamed: 12      object
# dtype: object

# %%
list = dataset[dataset['Gender'].str.startswith('M')]
maleList = list['CGPA'].tolist()
intervals = [2.0, 2.5, 3.0, 3.5, 4.0]
plt.hist(maleList, bins=intervals, ec='black')
plt.title("CGPA of all Male Students")
plt.xlabel("CGPA")
plt.ylabel("Number of Students")
plt.xticks(intervals)
plt.show()

# %%
randomlist = random.sample(range(0, 500), 21)
maleGrades = dataset[dataset['Gender'].str.startswith(
    'M')]["HSSC-1"].tolist()
femaleGrades = dataset[dataset['Gender'].str.startswith(
    'F')]["HSSC-1"].tolist()
maleGrades = maleGrades[:len(femaleGrades)]
plt.scatter(maleGrades, randomlist, marker='o', label="Male")
plt.scatter(femaleGrades, randomlist, marker='x', label="Female")
plt.xlabel('Marks Scored', fontsize=12)
plt.ylabel('Total Marks', fontsize=12)
plt.title("Marks of all Male vs Female Students")
plt.legend()
plt.show()

# %%
maleFavColor = dataset[dataset['Gender'].str.startswith(
    'M')]["FavoriteColor"].count()
femaleFavColor = dataset[dataset['Gender'].str.startswith(
    'F')]["FavoriteColor"].count()
favColor = dataset.groupby(["FavoriteColor", "Gender"]
                           ).size().unstack(level=1).plot(kind='bar')
plt.xlabel("Male")
plt.ylabel("Female")
plt.show()

# %%
birthMonth = dataset["BirthMonth"].tolist()
plt.plot(birthMonth, '-', label='birthMonth')
plt.xlabel("Students")
plt.ylabel("Birth Month")
plt.show()

# %%
marks = dataset.heatmap(dataset[["HSSC-1", "HSSC-2"]].corr(),
                   cmap='YlGnBu', annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-72b1a4e5cae4> in <module>
# ----> 1 marks = dataset.heatmap(dataset[["HSSC-1", "HSSC-2"]].corr(),
#       2                    cmap='YlGnBu', annot=True)
#       3 plt.show()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'heatmap'

# %%
#Name of the Students who have three names
dataset[dataset['Last Name'].str.count('w*')>0]
# Out:
#                               Name  Gender   HSSC-1    HSSC-2   CGPA  \
# 3              Syeda Maham Gillani  Female      412       440   3.11
# 6            Shahzada Mujahid Raza    Male      814       466    3.2
# 14           Muhammad Subhan Khan     Male      412       419   3.53
# 17            SARMAD WAHEED AHMED     Male      436       427   3.47
# 20               M Hassaan Lateef     Male      389       450    2.8
# 23                Ahmed Amjad Dar     Male      439       432   2.71
# 26         Muhammad Ibrahim Khalil    Male      340       357   2.88
# 32             Muhammad saim jamil    Male      320       849   2.85
# 33               Ahmar Hafeez Khan    Male      437       397   2.81
# 39            Muhammad Umar Asghar    Male      357       333   2.23
# 42            MUHAMMAD HAIDER AWAN    Male      60%       425   2.56
# 45             M.Abdul Mateen Alam    Male      345       390   2.93
# 46           Muhammad Ammar Khalid    Male  368/510       440   2.97
# 48              Osama Nadeem Khan     Male      350       389    2.8
# 51           Muhammad Hashir Azeem    Male      377       428    2.4
# 54               Muhammad Aun Raza    Male      339       320   2.96
# 55          Syeda Noor Zehra Naqvi  Female      428       420   3.05
# 58            Hafiz Malahim Labib.    Male      390       430   3.24
# 60             HAMNA TARIQ SALEEMI  Female      400       418    2.8
# 63          Bashara Tehseen Liaqat  Female      368       396   2.16
# 64        Muhammad zafar ijaz khan    Male      421       430    2.7
# 65            Muhammad Hammad Ejaz    Male      401       325    2.8
# 68             MUHAMMAD SAIF ULLAH    Male      293       799   3.11
# 69       Syed Muhammad Hamza Imran    Male      378       390   2.78
# 70               Muhammad Al Fahad    Male      412       346   2.35
# 72      Syed Ali Raza Shah Bukhari    Male      293       817  2.84.
# 76                 Abdul Hadi Khan    Male      315       368   3.23
# 78                Hamza Javed Khan    Male      400       381   3.39
# 83   Syed Muhammad Ali Abbas Naqvi    Male      380       341   2.65
# 96         Salman Wasi Ahmad Khan     Male      390       352   2.11
# 97           GHULAM MUSTAFA SHIEKH    Male      385       328   2.81
# 100        Muhammad Azeem Shoukat     Male      372       279   2.42
# 104          Muhammad Nouman Tahir    Male      412       442      3
# 106         Muhammad Huzaifa Jawad    Male      407       825    2.7
# 108                NOOR TARIQ RANA  Female      863       490   3.16
# 109        Muhammad Asadullah Rind    Male      374       404   2.69
# 110           Muhammad Talha Saeed    Male      382  768/1100   2.54
# 116           Muhammad Bilal Aslam    Male      421       400    2.6
# 117                 Syed Ali Mehdi    Male      384       829   2.57
# 118               Aftab Ahmad Khan    Male      494       422   2.27
# 122                 Syed Zain Raza    Male      394       436    2.8
# 123         Mutyyab Ul Hassan Khan    Male      383       441   2.58
# 124          Muhammad Umair Tariq     Male      402       407   3.45
# 129               M Abubakar Malik    Male      410       349   2.94
#
#     FavoriteColor BirthMonth Weight First Name Middle Name Last Name  \
# 3            Blue   February     63      Syeda       Maham   Gillani
# 6          Orange     August     60   Shahzada     Mujahid      Raza
# 14         Yellow   January      90   Muhammad      Subhan      Khan
# 17          Green    January   49.5     SARMAD      WAHEED     AHMED
# 20          Black  February      82          M     Hassaan    Lateef
# 23          Black       July     67      Ahmed       Amjad       Dar
# 26          Blue   November      60   Muhammad     Ibrahim    Khalil
# 32           blue   december     65   Muhammad        saim     jamil
# 33         Yellow   February     77      Ahmar      Hafeez      Khan
# 39          Black    October     62   Muhammad        Umar    Asghar
# 42           Blue    October     60   MUHAMMAD      HAIDER      AWAN
# 45        Purple   September     64    M.Abdul      Mateen      Alam
# 46          BLACK     August     72   Muhammad       Ammar    Khalid
# 48      Dark blue   February     53      Osama      Nadeem      Khan
# 51           Blue      March     53   Muhammad      Hashir     Azeem
# 54          Black    October     60   Muhammad         Aun      Raza
# 55         Yellow    October     67      Syeda        Noor     Zehra
# 58         Orange        May     54      Hafiz     Malahim    Labib.
# 60          Black    October     62      HAMNA       TARIQ   SALEEMI
# 63         Yellow   October      62    Bashara     Tehseen    Liaqat
# 64          Brown     August     64   Muhammad       zafar      ijaz
# 65    Light Green        May     52   Muhammad      Hammad      Ejaz
# 68         Black        June     66   MUHAMMAD        SAIF     ULLAH
# 69            Red   October      58       Syed    Muhammad     Hamza
# 70         Peach         May     54   Muhammad          Al     Fahad
# 72         Black     January     78       Syed         Ali      Raza
# 76          White       July     98      Abdul        Hadi      Khan
# 78           Blue   January      78      Hamza       Javed      Khan
# 83           Blue   Feburary     65       Syed    Muhammad       Ali
# 96           Blue     August     80     Salman        Wasi     Ahmad
# 97         Yellow   October      66     GHULAM     MUSTAFA    SHIEKH
# 100        Black   November      68   Muhammad       Azeem   Shoukat
# 104          Blue   February     59   Muhammad      Nouman     Tahir
# 106          Blue    October     60   Muhammad     Huzaifa     Jawad
# 108        Yellow    October     60       NOOR       TARIQ      RANA
# 109          Blue       July     60   Muhammad   Asadullah      Rind
# 110         Black      March     67   Muhammad       Talha     Saeed
# 116        Peach       March     74   Muhammad       Bilal     Aslam
# 117          Blue  December      68       Syed         Ali     Mehdi
# 118         Black   February     58      Aftab       Ahmad      Khan
# 122         Black   October      45       Syed        Zain      Raza
# 123         BLACK   October    80kg    Mutyyab          Ul    Hassan
# 124       Purple         May     65   Muhammad       Umair     Tariq
# 129          Blue   Feburary     65          M    Abubakar     Malik
#
#     Unnamed: 11 Unnamed: 12
# 3           NaN         NaN
# 6           NaN         NaN
# 14          NaN         NaN
# 17          NaN         NaN
# 20          NaN         NaN
# 23          NaN         NaN
# 26          NaN         NaN
# 32          NaN         NaN
# 33          NaN         NaN
# 39          NaN         NaN
# 42          NaN         NaN
# 45          NaN         NaN
# 46          NaN         NaN
# 48          NaN         NaN
# 51          NaN         NaN
# 54          NaN         NaN
# 55        Naqvi         NaN
# 58          NaN         NaN
# 60          NaN         NaN
# 63          NaN         NaN
# 64         khan         NaN
# 65          NaN         NaN
# 68          NaN         NaN
# 69        Imran         NaN
# 70          NaN         NaN
# 72         Shah     Bukhari
# 76          NaN         NaN
# 78          NaN         NaN
# 83        Abbas       Naqvi
# 96         Khan         NaN
# 97          NaN         NaN
# 100         NaN         NaN
# 104         NaN         NaN
# 106         NaN         NaN
# 108         NaN         NaN
# 109         NaN         NaN
# 110         NaN         NaN
# 116         NaN         NaN
# 117         NaN         NaN
# 118         NaN         NaN
# 122         NaN         NaN
# 123        Khan         NaN
# 124         NaN         NaN
# 129         NaN         NaN
